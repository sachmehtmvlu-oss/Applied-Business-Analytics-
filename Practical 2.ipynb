# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
print(df.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
math_scores = df["math score"]

# %%
print("Mean :", math_scores.mean())
# Out:
# Mean : 66.089

# %%
print("Median :", math_scores.median())
# Out:
# Median : 66.0

# %%
print("Mode :")
print(math_scores.mode())
# Out:
# Mode :
# 0    65
# Name: math score, dtype: int64

# %%
print("Minimum :", math_scores.min())
# Out:
# Minimum : 0

# %%
print("Maximum :", math_scores.max())
# Out:
# Maximum : 100

# %%
print("Range :", math_scores.max() - math_scores.min())
# Out:
# Range : 100

# %%
print("Variance :", math_scores.var())
# Out:
# Variance : 229.91899799799796

# %%
print("Standard Deviation :", math_scores.std())
# Out:
# Standard Deviation : 15.16308009600945

# %%
print("Count :", math_scores.count())
# Out:
# Count : 1000

# %%
print("Sum :", math_scores.sum())
# Out:
# Sum : 66089

# %%
print("\nDescriptive Statistics")
print(math_scores.describe())
# Out:
# Descriptive Statistics
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %% [markdown]
# # Practical 2B

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
math_scores = df["math score"]

# %%
plt.figure(figsize=(8,5))
plt.hist(math_scores, bins=10, color="skyblue", edgecolor="black")
plt.title("Histogram of Math Scores")
plt.xlabel("Math Score")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,3))
sns.boxplot(x=math_scores, color="orange")
plt.title("Box Plot of Math Scores")
plt.xlabel("Math Score")
plt.show()
